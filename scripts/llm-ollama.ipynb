# %%
import os
import subprocess
import threading

# %%
# Ones installed on my pc
model_names = [
    "llama3.1:latest",
    "olmo-3:7b-instruct",
    "olmo-3:latest",
    "granite3.3:latest",
    "ministral-3:latest",
    "qwen3:latest",   
    "deepseek-r1:latest",
    "gemma3:latest",
]

# %%
from langchain_ollama import ChatOllama

llm = ChatOllama(
    model=model_names[0],
    temperature=0,
    # other params...
)
messages = [
    (
        "system",
        "You are a helpful assistant that translates English to French. Translate the user sentence.",
    ),
    ("human", "I love programming."),
]
ai_msg = llm.invoke(messages)
ai_msg
# Out:
# AIMessage(content='The translation of "I love programming" in French is:\n\n"J\'adore le programmation."', additional_kwargs={}, response_metadata={'model': 'llama3.1:latest', 'created_at': '2025-12-20T17:42:10.153553939Z', 'done': True, 'done_reason': 'stop', 'total_duration': 606736149, 'load_duration': 125661556, 'prompt_eval_count': 35, 'prompt_eval_duration': 22895986, 'eval_count': 22, 'eval_duration': 431110377, 'logprobs': None, 'model_name': 'llama3.1:latest', 'model_provider': 'ollama'}, id='lc_run--019b3cda-c788-7310-9e98-cedd97710721-0', usage_metadata={'input_tokens': 35, 'output_tokens': 22, 'total_tokens': 57})

# %%
print(ai_msg.content)
print(ai_msg.response_metadata)
# Out:
# The translation of "I love programming" in French is:
#
# "J'adore le programmation."
# {'model': 'llama3.1:latest', 'created_at': '2025-12-20T17:42:10.153553939Z', 'done': True, 'done_reason': 'stop', 'total_duration': 606736149, 'load_duration': 125661556, 'prompt_eval_count': 35, 'prompt_eval_duration': 22895986, 'eval_count': 22, 'eval_duration': 431110377, 'logprobs': None, 'model_name': 'llama3.1:latest', 'model_provider': 'ollama'}
